# %%
# %%pyspark
# data_path = spark.read.load('abfss://novartisparquet@filedatalake.dfs.core.windows.net/part-00000-22b657e4-cb28-4263-bc64-f93e7581ed67-c000.snappy.parquet', format='parquet')
# data_path.show(100)
# Out:
# +----+-----+------------+-----------+----------+--------------+--------+------+-----------------+------+----------------+---------------+----+--------------+------------+--------+---------+-------------+---------+---------------+--------+----------+---------+-------+------------+--------+---------+-------------+---------+---------------+---------+-----------------+--------+----------------+-------------------+--------+-------+--------+--------------+-------------+-------------+---------+--------------+-------------------+----+
# ...

# %%
data_path.createOrReplaceTempView("flight_data")

# %%
# %%sql
#
#
# SELECT * from flight_data limit 10
